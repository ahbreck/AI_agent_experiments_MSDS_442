# %% [raw]
# ---
# keywords: [agent, agents]
# ---

# %% [markdown]
# # Build an Agent
#
# By themselves, language models can't take actions - they just output text.
# A big use case for LangChain is creating **agents**.
# [Agents](/docs/concepts/agents) are systems that use [LLMs](/docs/concepts/chat_models) as reasoning engines to determine which actions to take and the inputs necessary to perform the action.
# After executing actions, the results can be fed back into the LLM to determine whether more actions are needed, or whether it is okay to finish. This is often achieved via [tool-calling](/docs/concepts/tool_calling).
#
# In this tutorial we will build an agent that can interact with a search engine. You will be able to ask this agent questions, watch it call the search tool, and have conversations with it.
#
# ## End-to-end agent
#
# The code snippet below represents a fully functional agent that uses an LLM to decide which tools to use. It is equipped with a generic search tool. It has conversational memory - meaning that it can be used as a multi-turn chatbot.
#
# In the rest of the guide, we will walk through the individual components and what each part does - but if you want to just grab some code and get started, feel free to use this!

# %%
from dotenv import load_dotenv
import os

_ = load_dotenv(override=True)

LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")
LANGCHAIN_PROJECT = os.getenv("LANGCHAIN_PROJECT")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")
LANGCHAIN_TRACING_V2 = os.getenv("LANGCHAIN_TRACING_V2") == "true"

print("LANGCHAIN_PROJECT:", LANGCHAIN_PROJECT)
print("LANGCHAIN_TRACING_V2:", LANGCHAIN_TRACING_V2)
# Out:
# LANGCHAIN_PROJECT: MSDS_442_labs
# LANGCHAIN_TRACING_V2: True

# %%
# Import relevant functionality
#from langchain_anthropic import ChatAnthropic
from langchain_openai import ChatOpenAI

from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt import create_react_agent

# Create the agent
memory = MemorySaver()

#model = ChatAnthropic(model_name="claude-3-sonnet-20240229")
model = ChatOpenAI(model="gpt-4o-mini")


search = TavilySearchResults(max_results=2)
tools = [search]
agent_executor = create_react_agent(model, tools, checkpointer=memory)

# Use the agent
config = {"configurable": {"thread_id": "abc123"}}
for chunk in agent_executor.stream(
    {"messages": [HumanMessage(content="hi im bob! and i live in sf")]}, config
):
    print(chunk)
    print("----")

for chunk in agent_executor.stream(
    {"messages": [HumanMessage(content="whats the weather where I live?")]}, config
):
    print(chunk)
    print("----")
# Out:
# C:\Users\ahbre\AppData\Local\Temp\ipykernel_23232\446178353.py:19: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(model, tools, checkpointer=memory)
# {'agent': {'messages': [AIMessage(content="Hi Bob! Nice to meet you. How's it going in San Francisco?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 88, 'total_tokens': 105, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuKfYXbzw2XjoMfQJVSirHgB5SHRv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89b4-56a1-7110-bc42-abf6fd8fbf26-0', usage_metadata={'input_tokens': 88, 'output_tokens': 17, 'total_tokens': 105, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 120, 'total_tokens': 141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuKfaxsbAFkHCmbpr6qlXY4v6m1z6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b89b4-5e6d-7083-b82e-bf0708be5c02-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'San Francisco current weather'}, 'id': 'call_j6uld4weCcxC72KnUtlWbk2U', 'type': 'tool_call'}], usage_metadata={'input_tokens': 120, 'output_tokens': 21, 'total_tokens': 141, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----
# {'tools': {'messages': [ToolMessage(content='[{"title": "San Francisco weather in April 2026 | Weather25.com", "url": "https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=April", "content": "The wather in San Francisco in April can vary between cold and nice weather days. Expect a few rainy days but usually not more than 3.\\n\\nOur weather forecast can give you a great sense of what weather to expect in San Francisco in April 2026.\\n\\nIf you’re planning to visit San Francisco in the near future, we highly recommend that you review the 14 day weather forecast for San Francisco before you arrive.\\n\\n18° / 9°\\n\\nRainy Days\\n\\n2\\n\\nSnowy Days\\n\\n0\\n\\nDry Days\\n\\n28\\n\\nRainfall\\n\\n22\\n\\nmm\\n\\nSun Hours\\n\\n11.0 [...] What is the average temperature in San Francisco in April?\\n\\nThe average temperature in San Francisco in April is 9/18° C.\\n\\nWhat is the chance of rain in San Francisco in April?\\n\\nOn average, there are 2 rainy days in San Francisco during April.\\n\\nWeather wise, is April a good time to visit San Francisco?\\n\\nThe weather in San Francisco in April is good.\\n\\nCan it snow in San Francisco in April?\\n\\nOn average, there are 0 snowy days in San Francisco in April.\\n\\nMore about the weather in San Francisco [...] United States England Australia Canada\\n\\n°F °C\\n\\nSan Francisco\\n\\nWeather in April 2026\\n\\n1. Home\\n2. North America\\n3. United States\\n4. California\\n5. San Francisco\\n6. April\\n\\nLocation was added to My Locations\\n\\nLocation was removed from My Locations\\n\\n# San Francisco weather in April 2026\\n\\nThe temperatures in San Francisco in April are quite cold with temperatures between 9°C and 18°C, warm clothes are a must.", "score": 0.99947256}, {"title": "San Francisco, CA Monthly Weather | AccuWeather", "url": "https://www.accuweather.com/en/us/san-francisco/94103/january-weather/347629", "content": "### March 2026\\n\\n### April 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWinter Weather\\n\\nSeries of storms to bring slippery travel to Great Lakes, Northeast\\n\\n3 hours ago\\n\\nWinter Weather\\n\\nEarly 2026 rain, mountain snow to expand in California and western US\\n\\n4 hours ago\\n\\nWinter Weather\\n\\n80 inches of snow in Juneau, Alaska smashes record, sinks boats\\n\\n3 days ago\\n\\nWeather Forecasts [...] Full moons and supermoons in 2026: Every date to know\\n\\n2 hours ago\\n\\n## Weather Near San Francisco:\\n\\n...\\n\\n...\\n\\n... [...] # San Francisco, CA\\n\\nSan Francisco\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## January\\n\\n## 2026\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### February 2026", "score": 0.7718435}]', name='tavily_search_results_json', id='22fe0d7f-69e0-4dd4-8211-3004bb77cf9c', tool_call_id='call_j6uld4weCcxC72KnUtlWbk2U', artifact={'query': 'San Francisco current weather', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=April', 'title': 'San Francisco weather in April 2026 | Weather25.com', 'content': 'The wather in San Francisco in April can vary between cold and nice weather days. Expect a few rainy days but usually not more than 3.\n\nOur weather forecast can give you a great sense of what weather to expect in San Francisco in April 2026.\n\nIf you’re planning  ...
# ----
# {'agent': {'messages': [AIMessage(content="It looks like I couldn't get the current weather information for San Francisco directly. However, generally, in April, the temperatures in San Francisco can range from around 9°C (48°F) to 18°C (64°F), and you can expect a few rainy days. \n\nFor the most accurate and up-to-date weather, I recommend checking a local weather website or app. Would you like me to help you with anything else?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 968, 'total_tokens': 1056, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuKfhfC3kHtI9BuMvSKApTYnJMJWD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89b4-7885-78d0-a73d-7b64eed10fdb-0', usage_metadata={'input_tokens': 968, 'output_tokens': 88, 'total_tokens': 1056, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----

# %% [markdown]
# ## Setup
#
# ### Jupyter Notebook
#
# This guide (and most of the other guides in the documentation) uses [Jupyter notebooks](https://jupyter.org/) and assumes the reader is as well. Jupyter notebooks are perfect interactive environments for learning how to work with LLM systems because oftentimes things can go wrong (unexpected output, API down, etc), and observing these cases is a great way to better understand building with LLMs.
#
# This and other tutorials are perhaps most conveniently run in a Jupyter notebook. See [here](https://jupyter.org/install) for instructions on how to install.
#
# ### Installation
#
# To install LangChain run:

# %%
#%pip install -U langchain-community langgraph langchain-openai tavily-python langgraph-checkpoint-sqlite
# Out:
# Requirement already satisfied: langchain-community in c:\workbench\langchain-langgraph\venv\lib\site-packages (0.3.8)
# Requirement already satisfied: langgraph in c:\workbench\langchain-langgraph\venv\lib\site-packages (0.2.53)
# Requirement already satisfied: langchain-openai in c:\workbench\langchain-langgraph\venv\lib\site-packages (0.2.10)
# Requirement already satisfied: tavily-python in c:\workbench\langchain-langgraph\venv\lib\site-packages (0.5.0)
# Requirement already satisfied: langgraph-checkpoint-sqlite in c:\workbench\langchain-langgraph\venv\lib\site-packages (2.0.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (3.9.0b0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.8 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (0.3.9)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (0.3.21)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (0.1.147)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.4 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langgraph) (2.0.7)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.32 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langgraph) (0.1.40)
# Requirement already satisfied: openai<2.0.0,>=1.54.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-openai) (1.55.3)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: httpx in c:\workbench\langchain-langgraph\venv\lib\site-packages (from tavily-python) (0.27.2)
# Requirement already satisfied: aiosqlite<0.21.0,>=0.20.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langgraph-checkpoint-sqlite) (0.20.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: typing_extensions>=4.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from aiosqlite<0.21.0,>=0.20.0->langgraph-checkpoint-sqlite) (4.12.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain<0.4.0,>=0.3.8->langchain-community) (0.3.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain<0.4.0,>=0.3.8->langchain-community) (2.10.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-community) (24.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.0.4->langgraph) (1.1.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langgraph-sdk<0.2.0,>=0.1.32->langgraph) (3.10.12)
# Requirement already satisfied: anyio in c:\workbench\langchain-langgraph\venv\lib\site-packages (from httpx->tavily-python) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\workbench\langchain-langgraph\venv\lib\site-packages (from httpx->tavily-python) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\workbench\langchain-langgraph\venv\lib\site-packages (from httpx->tavily-python) (1.0.7)
# Requirement already satisfied: idna in c:\workbench\langchain-langgraph\venv\lib\site-packages (from httpx->tavily-python) (3.10)
# Requirement already satisfied: sniffio in c:\workbench\langchain-langgraph\venv\lib\site-packages (from httpx->tavily-python) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from httpcore==1.*->httpx->tavily-python) (0.14.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.8.0)
# Requirement already satisfied: tqdm>4 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.67.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from SQLAlchemy<2.0.36,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from anyio->httpx->tavily-python) (1.2.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.8->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.8->langchain-community) (2.27.1)
# Requirement already satisfied: colorama in c:\workbench\langchain-langgraph\venv\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.54.0->langchain-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\workbench\langchain-langgraph\venv\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# For more details, see our [Installation guide](/docs/how_to/installation).
#
# ### LangSmith
#
# Many of the applications you build with LangChain will contain multiple steps with multiple invocations of LLM calls.
# As these applications get more and more complex, it becomes crucial to be able to inspect what exactly is going on inside your chain or agent.
# The best way to do this is with [LangSmith](https://smith.langchain.com).
#
# After you sign up at the link above, make sure to set your environment variables to start logging traces:
#
# ```shell
# export LANGCHAIN_TRACING_V2="true"
# export LANGCHAIN_API_KEY="..."
# ```
#
# Or, if in a notebook, you can set them with:
#
# ```python
# import getpass
# import os
#
# os.environ["LANGCHAIN_TRACING_V2"] = "true"
# os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()
# ```
#
# ### Tavily
#
# We will be using [Tavily](/docs/integrations/tools/tavily_search) (a search engine) as a tool.
# In order to use it, you will need to get and set an API key:
#
# ```bash
# export TAVILY_API_KEY="..."
# ```
#
# Or, if in a notebook, you can set it with:
#
# ```python
# import getpass
# import os
#
# os.environ["TAVILY_API_KEY"] = getpass.getpass()
# ```

# %% [markdown]
# ## Define tools
#
# We first need to create the tools we want to use. Our main tool of choice will be [Tavily](/docs/integrations/tools/tavily_search) - a search engine. We have a built-in tool in LangChain to easily use Tavily search engine as tool.

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

search = TavilySearchResults(max_results=2)
search_results = search.invoke("what is the weather in SF")
print(search_results)
# If we want, we can create other tools.
# Once we have all the tools we want, we can put them in a list that we will reference later.
tools = [search]
# Out:
# [{'title': 'San Francisco weather in April 2026 | California, USA', 'url': 'https://www.weather2travel.com/california/san-francisco/april/', 'content': 'Home\n North America\n USA\n California\n San Francisco\n Weather in April\n\n# San Francisco weather in April 2026\n\nExpect  daytime maximum temperatures of 17°C in San Francisco, California in April based on long-term weather averages. There are 10 hours of sunshine per day on average with typically 40 mm of rainfall in the month.\n\n 17°C max day temperature\n 10 hours of sunshine per day\n 6 days with some rainfall\n 9°C min night temperature\n 13 hours of daylight per day\n 0\n\n  No heat & humidity\n 40', 'score': 0.99937373}, {'title': 'Weather San Francisco in April 2026: Temperature & Climate', 'url': 'https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/april-4/', 'content': "April in San Francisco offers a mild and comfortable climate, ideal for exploring the city's numerous attractions. The average temperature during this month is around 54.5°F (12.5°C), providing a pleasant atmosphere for both locals and tourists. Daytime highs typically reach about 63.3°F (17.4°C), perfect for outdoor activities like walking across the Golden Gate Bridge or visiting Alcatraz Island. Meanwhile, nighttime lows generally dip to around 48°F (8.9°C), so it's wise to carry a light [...] The warmest day in San Francisco during April is 30.04, reaching 20.2°C | 68.3°F,\nwhile 08.04 stands out as the coldest, with 8.2°C | 46.7°F.\nIn the first ten days, highs average 16.7°C | 62.1°F, and lows are around 8.5°C | 47.3°F.\nFrom the 11th to the 20th, expect highs near 17.3°C | 63.1°F and lows of about 9°C | 48.2°F.\nDuring the final third, temperatures average 18.7°C | 65.7°F for highs and 9.6°C | 49.3°F for lows. [...] The warmest day in San Francisco during April is 30.04, reaching 20.2°C | 68.3°F,\nwhile 08.04 stands out as the coldest, with 8.2°C | 46.7°F.\nIn the first ten days, highs average 16.7°C | 62.1°F, and lows are around 8.5°C | 47.3°F.\nFrom the 11th to the 20th, expect highs near 17.3°C | 63.1°F and lows of about 9°C | 48.2°F.\nDuring the final third, temperatures average 18.7°C | 65.7°F for highs and 9.6°C | 49.3°F for lows.", 'score': 0.9992679}]

# %% [markdown]
# ## Using Language Models
#
# Next, let's learn how to use a language model by to call tools. LangChain supports many different language models that you can use interchangably - select the one you want to use below!
#
# import ChatModelTabs from "@theme/ChatModelTabs";
#
# <ChatModelTabs openaiParams={`model="gpt-4"`} />

# %%
# | output: false
# | echo: false

#from langchain_anthropic import ChatAnthropic
#model = ChatAnthropic(model="claude-3-sonnet-20240229")

from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o-mini")

# %% [markdown]
# You can call the language model by passing in a list of messages. By default, the response is a `content` string.

# %%
from langchain_core.messages import HumanMessage

response = model.invoke([HumanMessage(content="hi!")])
response.content
# Out:
# 'Hello! How can I assist you today?'

# %% [markdown]
# We can now see what it is like to enable this model to do tool calling. In order to enable that we use `.bind_tools` to give the language model knowledge of these tools

# %%
model_with_tools = model.bind_tools(tools)

# %% [markdown]
# We can now call the model. Let's first call it with a normal message, and see how it responds. We can look at both the `content` field as well as the `tool_calls` field.

# %%
response = model_with_tools.invoke([HumanMessage(content="Hi!")])

print(f"ContentString: {response.content}")
print(f"ToolCalls: {response.tool_calls}")
# Out:
# ContentString: Hello! How can I assist you today?
# ToolCalls: []

# %% [markdown]
# Now, let's try calling it with some input that would expect a tool to be called.

# %%
response = model_with_tools.invoke([HumanMessage(content="What's the weather in SF?")])

print(f"ContentString: {response.content}")
print(f"ToolCalls: {response.tool_calls}")
# Out:
# ContentString:
# ToolCalls: [{'name': 'tavily_search_results_json', 'args': {'query': 'San Francisco current weather'}, 'id': 'call_aPWm3Gq4qTIzerQP1efN197l', 'type': 'tool_call'}]

# %% [markdown]
# We can see that there's now no text content, but there is a tool call! It wants us to call the Tavily Search tool.
#
# This isn't calling that tool yet - it's just telling us to. In order to actually call it, we'll want to create our agent.

# %% [markdown]
# ## Create the agent
#
# Now that we have defined the tools and the LLM, we can create the agent. We will be using [LangGraph](/docs/concepts/architecture/#langgraph) to construct the agent.
# Currently, we are using a high level interface to construct the agent, but the nice thing about LangGraph is that this high-level interface is backed by a low-level, highly controllable API in case you want to modify the agent logic.

# %% [markdown]
# Now, we can initialize the agent with the LLM and the tools.
#
# Note that we are passing in the `model`, not `model_with_tools`. That is because `create_react_agent` will call `.bind_tools` for us under the hood.

# %%
from langgraph.prebuilt import create_react_agent

agent_executor = create_react_agent(model, tools)
# Out:
# C:\Users\ahbre\AppData\Local\Temp\ipykernel_23232\1543831842.py:3: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(model, tools)

# %% [markdown]
# ## Run the agent
#
# We can now run the agent with a few queries! Note that for now, these are all **stateless** queries (it won't remember previous interactions). Note that the agent will return the **final** state at the end of the interaction (which includes any inputs, we will see later on how to get only the outputs).
#
# First up, let's see how it responds when there's no need to call a tool:

# %%
response = agent_executor.invoke({"messages": [HumanMessage(content="hi!")]})

response["messages"]
# Out:
# [HumanMessage(content='hi!', additional_kwargs={}, response_metadata={}, id='a1278c11-db42-44ef-9aea-67f7ceee3c4b'),
#  AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 81, 'total_tokens': 91, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL067wmEJn4LEogcJ1gWgUN9B6hq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89c7-c2a6-7d02-a8ab-c33d75744a6c-0', usage_metadata={'input_tokens': 81, 'output_tokens': 10, 'total_tokens': 91, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %% [markdown]
# In order to see exactly what is happening under the hood (and to make sure it's not calling a tool) we can take a look at the [LangSmith trace](https://smith.langchain.com/public/28311faa-e135-4d6a-ab6b-caecf6482aaa/r)
#
# Let's now try it out on an example where it should be invoking the tool

# %%
response = agent_executor.invoke(
    {"messages": [HumanMessage(content="whats the weather in sf?")]}
)
response["messages"]
# Out:
# [HumanMessage(content='whats the weather in sf?', additional_kwargs={}, response_metadata={}, id='94d206e1-dd65-4a3c-bb30-ff97dc01578f'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 86, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL16tMHpMqjQVruKm23SHH77aNfw', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b89c8-b3aa-7100-a226-6d2b0255751d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather San Francisco'}, 'id': 'call_ROqt9ioCNO6HTZOdIojkNHRa', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 21, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='[{"title": "San Francisco weather in April 2026 | Weather25.com", "url": "https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=April", "content": "weather25.com\\nSearch\\nweather in United States\\nRemove from your favorite locations\\nAdd to my locations\\nShare\\nweather in United States\\n\\n# San Francisco weather in April 2026\\n\\nThe temperatures in San Francisco in April are quite cold with temperatures between 9°C and 18°C, warm clothes are a must.\\n\\nThe wather in San Francisco in April can vary between cold and nice weather days. Expect a few rainy days but usually not more than 3. [...] Our weather forecast can give you a great sense of what weather to expect in San Francisco in April 2026.\\n\\nIf you’re planning to visit San Francisco in the near future, we highly recommend that you review the 14 day weather forecast for San Francisco before you arrive.\\n\\nTemperatures\\nRainy Days\\nSnowy Days\\nDry Days\\nRainfall\\n11.0 [...] | 12 Partly cloudy 15° /8° | 13 Partly cloudy 15° /8° | 14 Sunny 15° /9° | 15 Sunny 16° /9° | 16 Partly cloudy 16° /9° | 17 Overcast 15° /9° | 18 Partly cloudy 16° /10° |\\n| 19 Partly cloudy 15° /10° | 20 Partly cloudy 15° /9° | 21 Partly cloudy 17° /10° | 22 Partly cloudy 16° /10° | 23 Partly cloudy 16° /10° | 24 Sunny 16° /10° | 25 Overcast 15° /10° |\\n| 26 Partly cloudy 17° /10° | 27 Partly cloudy 17° /10° | 28 Sunny 18° /11° | 29 Overcast 17° /10° | 30 Overcast 17° /10° |  |  |", "score": 0.8896154}, {"title": "San Francisco, CA Monthly Weather | AccuWeather", "url": "https://www.accuweather.com/en/us/san-francisco/94103/january-weather/347629", "content": "### March 2026\\n\\n### April 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWinter Weather\\n\\nSeries of storms to bring slippery travel to Great Lakes, Northeast\\n\\n3 hours ago\\n\\nWinter Weather\\n\\nEarly 2026 rain, mountain snow to expand in California and western US\\n\\n5 hours ago\\n\\nWinter Weather\\n\\n80 inches of snow in Juneau, Alaska smashes record, sinks boats\\n\\n3 days ago\\n\\nWeather Forecasts [...] Full moons and supermoons in 2026: Every date to know\\n\\n3 hours ago\\n\\n## Weather Near San Francisco:\\n\\n...\\n\\n...\\n\\n... [...] # San Francisco, CA\\n\\nSan Francisco\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## January\\n\\n## 2026\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### February 2026", "score": 0.63288915}]', name='tavily_search_results_json', id='4d5241c2-5628-4dcf-b546-b809c9c5a663', tool_call_id='call_ROqt9ioCNO6HTZOdIojkNHRa', artifact={'query': 'current weather San Francisco', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=April', 'title': 'San Francisco weather in April 2026 | Weather25.com', 'content': 'weather25.com\nSearch\nweather in United States\nRemove from your favorite locations\nAdd to my locations\nShare\nweather in United States\n\n# San Francisco weather in April 2026\n\nThe temperatures in San Francisco in April are quite cold with temperatures between 9°C and 18°C, warm clothes are a must.\n\nThe wather in San Francisco in April can vary between cold and nice weather days. Expect a few rainy days but usually not more than 3. [...] Our weather forecast can give you a great sense of what weather to expect  ...
#  AIMessage(content="It seems I'm unable to get the current weather for San Francisco directly. However, you can typically expect cool temperatures around this time of year, often ranging between 15°C to 18°C (59°F to 64°F) during the day, and cooler at night. Rain is possible, but it’s often interspersed with sunny or partly cloudy days.\n\nFor the latest updates, you might want to check reliable sources like [AccuWeather](https://www.accuweather.com/en/us/san-francisco/94103/january-weather/347629).", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 116, 'prompt_tokens': 969, 'total_tokens': 1085, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL1EhhKgcQvK0ef6UaL7Soszq21E', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89c8-d79d-79c3-be5e-36393afc726e-0', usage_metadata={'input_tokens': 969, 'output_tokens': 116, 'total_tokens': 1085, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %% [markdown]
# We can check out the [LangSmith trace](https://smith.langchain.com/public/f520839d-cd4d-4495-8764-e32b548e235d/r) to make sure it's calling the search tool effectively.

# %% [markdown]
# ## Streaming Messages
#
# We've seen how the agent can be called with `.invoke` to get  a final response. If the agent executes multiple steps, this may take a while. To show intermediate progress, we can stream back messages as they occur.

# %%
for chunk in agent_executor.stream(
    {"messages": [HumanMessage(content="whats the weather in sf?")]}
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 86, 'total_tokens': 106, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL2Q9eChcowQ5Rim6UnLfJS4MqmL', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b89c9-fa89-75b1-9270-9b3c9633de37-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'San Francisco weather'}, 'id': 'call_dDXAKbdAkW31v2xlmamJP6x2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 20, 'total_tokens': 106, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----
# {'tools': {'messages': [ToolMessage(content='[{"title": "San Francisco weather in April 2026 | California, USA", "url": "https://www.weather2travel.com/california/san-francisco/april/", "content": "Home\\n North America\\n USA\\n California\\n San Francisco\\n Weather in April\\n\\n# San Francisco weather in April 2026\\n\\nExpect  daytime maximum temperatures of 17°C in San Francisco, California in April based on long-term weather averages. There are 10 hours of sunshine per day on average with typically 40 mm of rainfall in the month.\\n\\n 17°C max day temperature\\n 10 hours of sunshine per day\\n 6 days with some rainfall\\n 9°C min night temperature\\n 13 hours of daylight per day\\n 0\\n\\n  No heat & humidity\\n 40 [...] | Date | Sunrise times | Sunset times |\\n --- \\n| Wednesday, 1st April 2026 | 05:55 | 18:33 |\\n| Wednesday, 15th April 2026 | 05:34 | 18:46 |\\n| Thursday, 30th April 2026 | 05:15 | 18:59 |\\n\\n## Be inspired\\n\\nGet your weekly fix of holiday inspiration from some of the world\'s best travel writers plus save on your next trip with the latest exclusive offers\\n\\nWe promise not to share your details\\n\\n## Related posts [...] There are usually 3 days with some rain in San Francisco in April and the average monthly rainfall is 29mm.\\n\\n## San Francisco April sunrise & sunset times\\n\\nBrowse the sunrise and sunset times for San Francisco in April 2026. Select a month to view San Francisco sunrise and sunset times for the next 12 months.\\n\\nJanFebMarAprMayJunJulAugSepOctNovDec", "score": 0.93468803}, {"title": "San Francisco weather in April 2026", "url": "https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=April", "content": "The wather in San Francisco in April can vary between cold and nice weather days. Expect a few rainy days but usually not more than 3.\\n\\nOur weather forecast can give you a great sense of what weather to expect in San Francisco in April 2026.\\n\\nIf you’re planning to visit San Francisco in the near future, we highly recommend that you review the 14 day weather forecast for San Francisco before you arrive.\\n\\n18° / 9°\\n\\nRainy Days\\n\\n2\\n\\nSnowy Days\\n\\n0\\n\\nDry Days\\n\\n28\\n\\nRainfall\\n\\n22\\n\\nmm\\n\\nSun Hours\\n\\n11.0 [...] United States England Australia Canada\\n\\n°F °C\\n\\nSan Francisco\\n\\nWeather in April 2026\\n\\n1. Home\\n2. North America\\n3. United States\\n4. California\\n5. San Francisco\\n6. April\\n\\nLocation was added to My Locations\\n\\nLocation was removed from My Locations\\n\\n# San Francisco weather in April 2026\\n\\nThe temperatures in San Francisco in April are quite cold with temperatures between 9°C and 18°C, warm clothes are a must. [...] What is the average temperature in San Francisco in April?\\n\\nThe average temperature in San Francisco in April is 9/18° C.\\n\\nWhat is the chance of rain in San Francisco in April?\\n\\nOn average, there are 2 rainy days in San Francisco during April.\\n\\nWeather wise, is April a good time to visit San Francisco?\\n\\nThe weather in San Francisco in April is good.\\n\\nCan it snow in San Francisco in April?\\n\\nOn average, there are 0 snowy days in San Francisco in April.\\n\\nMore about the weather in San Francisco", "score": 0.92794675}]', name='tavily_search_results_json', id='96d79055-0b26-423d-897c-89aef1820194', tool_call_id='call_dDXAKbdAkW31v2xlmamJP6x2', artifact={'query': 'San Francisco weather', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.weather2travel.com/california/san-francisco/april/', 'title': 'San Francisco weather in April 2026 | California, USA', 'content': "Home\n North America\n USA\n California\n San Francisco\n Weather in April\n\n# San Francisco weather in April 2026\n\nExpect  daytime maximum temperatures of 17°C in San Francisco, California in April based on long-term weather averages. There are 10 hours of sunshine per day on average with typically 40 mm of rainfa ...
# ----
# {'agent': {'messages': [AIMessage(content="The current weather in San Francisco can vary, but generally for April, you can expect:\n\n- Daytime maximum temperatures around 17-18°C (about 63-64°F).\n- Nighttime minimum temperatures around 9°C (about 48°F).\n- Approximately 10 hours of sunshine per day.\n- An average of about 2-3 rainy days throughout the month with total rainfall around 22-40 mm.\n\nIf you are planning to visit, it's a good idea to check a detailed forecast closer to your date.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 108, 'prompt_tokens': 937, 'total_tokens': 1045, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL2WvbeUEXDSoOFRt7PNZFmxE6Fn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89ca-13b8-72e2-b234-77f0144d452f-0', usage_metadata={'input_tokens': 937, 'output_tokens': 108, 'total_tokens': 1045, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----

# %% [markdown]
# ## Streaming tokens
#
# In addition to streaming back messages, it is also useful to stream back tokens.
# We can do this with the `.astream_events` method.
#
# :::important
# This `.astream_events` method only works with Python 3.11 or higher.
# :::

# %%
async for event in agent_executor.astream_events(
    {"messages": [HumanMessage(content="whats the weather in sf?")]}, version="v1"
):
    kind = event["event"]
    if kind == "on_chain_start":
        if (
            event["name"] == "Agent"
        ):  # Was assigned when creating the agent with `.with_config({"run_name": "Agent"})`
            print(
                f"Starting agent: {event['name']} with input: {event['data'].get('input')}"
            )
    elif kind == "on_chain_end":
        if (
            event["name"] == "Agent"
        ):  # Was assigned when creating the agent with `.with_config({"run_name": "Agent"})`
            print()
            print("--")
            print(
                f"Done agent: {event['name']} with output: {event['data'].get('output')['output']}"
            )
    if kind == "on_chat_model_stream":
        content = event["data"]["chunk"].content
        if content:
            # Empty content in the context of OpenAI means
            # that the model is asking for a tool to be invoked.
            # So we only print non-empty content
            print(content, end="|")
    elif kind == "on_tool_start":
        print("--")
        print(
            f"Starting tool: {event['name']} with inputs: {event['data'].get('input')}"
        )
    elif kind == "on_tool_end":
        print(f"Done tool: {event['name']}")
        print(f"Tool output was: {event['data'].get('output')}")
        print("--")
# Out:
# --
# Starting tool: tavily_search_results_json with inputs: {'query': 'weather in San Francisco'}
# Done tool: tavily_search_results_json
# Tool output was: content='[{"title": "Weather San Francisco in April 2026", "url": "https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/april-4/", "content": "In San Francisco, average temperatures in April are around 12.7°C | 54.9°F. The water is usually 11.3°C | 52.3°F in the first third of the month, rises to 11.2°C | 52.2°F by mid-month, and finishes at about 11.2°C | 52.2°F by month’s end. [...] In San Francisco, average temperatures in April are around 12.7°C | 54.9°F. The water is usually 11.3°C | 52.3°F in the first third of the month, rises to 11.2°C | 52.2°F by mid-month, and finishes at about 11.2°C | 52.2°F by month’s end. [...] April in San Francisco offers a mild and comfortable climate, ideal for exploring the city\'s numerous attractions. The average temperature during this month is around 54.5°F (12.5°C), providing a pleasant atmosphere for both locals and tourists. Daytime highs typically reach about 63.3°F (17.4°C), perfect for outdoor activities like walking across the Golden Gate Bridge or visiting Alcatraz Island. Meanwhile, nighttime lows generally dip to around 48°F (8.9°C), so it\'s wise to carry a light", "score": 0.9997658}, {"title": "San Francisco weather in April 2026 | California, USA", "url": "https://www.weather2travel.com/california/san-francisco/april/", "content": "Home\\n North America\\n USA\\n California\\n San Francisco\\n Weather in April\\n\\n# San Francisco weather in April 2026\\n\\nExpect  daytime maximum temperatures of 17°C in San Francisco, California in April based on long-term weather averages. There are 10 hours of sunshine per day on average with typically 40 mm of rainfall in the month.\\n\\n 17°C max day temperature\\n 10 hours of sunshine per day\\n 6 days with some rainfall\\n 9°C min night temperature\\n 13 hours of daylight per day\\n 0\\n\\n  No heat & humidity\\n 40", "score": 0.9997017}]' name='tavily_search_results_json' tool_call_id='call_BaQaOBJ25bfLm3bSE6stx4G6' artifact={'query': 'weather in San Francisco', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/april-4/', 'title': 'Weather San Francisco in April 2026', 'content': "In San Francisco, average temperatures in April are around 12.7°C | 54.9°F. The water is usually 11.3°C | 52.3°F in the first third of the month, rises to 11.2°C | 52.2°F by mid-month, and finishes at about 11.2°C | 52.2°F by month’s end. [...] In San Francisco, average temperatures in April are around 12.7°C | 54.9°F. The water is usually 11.3°C | 52.3°F in the first third of the month, rises to 11.2°C | 52.2°F by mid-month, and finishes at about 11.2°C | 52.2°F by month’s end. [...] April in San Francisco offers a mild and comfortable climate, ideal for exploring the city's numerous attractions. The average temperature during this month is around 54.5°F (12.5°C), providing a pleasant atmosphere for both locals and tourists. Daytime highs typically reach about 63.3°F (17.4°C), perfect for outdoor activities like walking across the Golden Gate Bridge or visiting Alcatraz Island. Meanwhile, nighttime lows generally dip to around 48°F (8.9°C), so it's wise to carry a light", 'score': 0.9997658, 'raw_content': None}, {'url': 'https://www.weather2travel.com/california/san-francisco/april/', 'title': 'San Francisco weather in April 2026 | California, USA', 'content': 'Home\n North America\n USA\n California\n San Francisco\n Weather in April\n\n# San Francisco weather in April 2026\n\nExpect  daytime maximum temperatures of 17°C in San Francisco, California in April based on long-term weather averages. There are 10 hours of sunshine per day on average with typically 40 mm of rainfall in the month.\n\n 17°C max day temperature\n 10 hours of sunshine per day\n 6 days with some rainfall\n 9°C min night temperature\n 13 hours of daylight per day\n 0\n\n  No heat & humidity\n 40' ...
# --
# The| current| weather| in| San| Francisco| isn't| explicitly| available|,| but| I| can| provide| you| with| some| general| information| about| the| typical| April| weather| there|.| In| April|,| San| Francisco| experiences| average| daytime| temperatures| around| |17|°C| (|63|°F|)| and| nighttime| lows| of| about| |9|°C| (|48|°F|).| You| can| expect| around| |10| hours| of| sunshine| per| day|,| with| an| average| of| |40| mm| of| rainfall| throughout| the| month|.
#
# |For| the| most| accurate| and| up|-to|-date| weather| conditions|,| you| might| want| to| check| a| dedicated| weather| service|.|

# %% [markdown]
# ## Adding in memory
#
# As mentioned earlier, this agent is stateless. This means it does not remember previous interactions. To give it memory we need to pass in a checkpointer. When passing in a checkpointer, we also have to pass in a `thread_id` when invoking the agent (so it knows which thread/conversation to resume from).

# %%
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()

# %%
agent_executor = create_react_agent(model, tools, checkpointer=memory)

config = {"configurable": {"thread_id": "abc123"}}
# Out:
# C:\Users\ahbre\AppData\Local\Temp\ipykernel_23232\4203846759.py:1: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(model, tools, checkpointer=memory)

# %%
for chunk in agent_executor.stream(
    {"messages": [HumanMessage(content="hi im bob!")]}, config
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content='Hi Bob! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 83, 'total_tokens': 94, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL4GoyNzxd7rgsCk6l9TYoUxjxlT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89cb-b96b-79b2-9add-f751d196fe75-0', usage_metadata={'input_tokens': 83, 'output_tokens': 11, 'total_tokens': 94, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----

# %%
for chunk in agent_executor.stream(
    {"messages": [HumanMessage(content="whats my name?")]}, config
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content='Your name is Bob! How can I help you, Bob?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 106, 'total_tokens': 120, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL4Qhj9hlmvdLcKX5aLN6Wyprq30', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89cb-df24-7dc2-bf91-1006b2feca76-0', usage_metadata={'input_tokens': 106, 'output_tokens': 14, 'total_tokens': 120, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----

# %% [markdown]
# Example [LangSmith trace](https://smith.langchain.com/public/fa73960b-0f7d-4910-b73d-757a12f33b2b/r)

# %% [markdown]
# If you want to start a new conversation, all you have to do is change the `thread_id` used

# %%
config = {"configurable": {"thread_id": "xyz123"}}
for chunk in agent_executor.stream(
    {"messages": [HumanMessage(content="whats my name?")]}, config
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content="I'm sorry, but I don't have access to personal information about you unless you've shared it in this conversation. If you'd like me to address you by a specific name, please let me know!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 84, 'total_tokens': 123, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL4dcJBEwmu5lqxKCHAr8rwIe6rf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89cc-10bf-7493-b654-75b3cc01c6d7-0', usage_metadata={'input_tokens': 84, 'output_tokens': 39, 'total_tokens': 123, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----

# %%
config = {"configurable": {"thread_id": "egg988"}}
for chunk in agent_executor.stream(
    {"messages": [HumanMessage(content="Hi I'm Andrew and I live in Boston, Massachusetts!")]}, config
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content="Hello Andrew! It's great to meet you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 90, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL54Oa6BmO2MKDbQ2ZwAIlyekejV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89cc-53c6-73d1-8cbf-6de1593e6ea4-0', usage_metadata={'input_tokens': 90, 'output_tokens': 17, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----

# %%
for chunk in agent_executor.stream(
    {"messages": [HumanMessage(content="Where do I live?")]}, config
):
    print(chunk)
    print("----")
# Out:
# {'agent': {'messages': [AIMessage(content='You live in Boston, Massachusetts. If you have any questions about your city or need assistance with something specific, let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 161, 'total_tokens': 188, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CuL5jKz6H4J640t3uZl66cgEYUqkN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b89cd-1e1a-7772-b6f1-3cdb174a1eed-0', usage_metadata={'input_tokens': 161, 'output_tokens': 27, 'total_tokens': 188, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ----

# %% [markdown]
# ## Conclusion
#
# That's a wrap! In this quick start we covered how to create a simple agent.
# We've then shown how to stream back a response - not only with the intermediate steps, but also tokens!
# We've also added in memory so you can have a conversation with them.
# Agents are a complex topic with lots to learn!
#
# For more information on Agents, please check out the [LangGraph](/docs/concepts/architecture/#langgraph) documentation. This has it's own set of concepts, tutorials, and how-to guides.
